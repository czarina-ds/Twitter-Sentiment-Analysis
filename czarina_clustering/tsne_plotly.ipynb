# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
data = pd.read_csv('cleaned_tweets.csv').dropna(subset=['clean'])

# %%
from sklearn.model_selection import train_test_split
X = data['clean']
y = data['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=112221, stratify=y)

# %%
from gensim.models import Word2Vec
from nltk import word_tokenize

X_train_token = X_train.map(word_tokenize)

# %%
word2vec_model = Word2Vec(X_train_token, window=5, min_count=1, workers=4)

word2vec_model.train(X_train_token, total_examples=word2vec_model.corpus_count, epochs=word2vec_model.epochs)
# Out:
# (213832, 247340)

# %%
# w2v = Word2Vec(X_train_token, size=150, window=10, min_count=10, workers=10)            

# w2v.train(X_train_token, total_examples=len(X_train_token), epochs=10)
# Out:
# (278615, 494680)

# %%
import warnings
warnings.filterwarnings('ignore')

labels = []
tokens = []
for word in word2vec_model.wv.vocab:
    tokens.append(word2vec_model[word])
    labels.append(word)

# %%
from sklearn.manifold import TSNE
tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500)
new_values = tsne_model.fit_transform(tokens)
x = []
y = []
for value in new_values:
    x.append(value[0])
    y.append(value[1])

# %%
axis_dict = {'autorange': True, 'showgrid': False, 'zeroline': False, 'showline': False, 'ticks': '', 'showticklabels': False}
init_notebook_mode(connected=True)
plot_data = go.Scatter(x=x, y=y, mode='markers+text', marker = {'size': 4, 'color': '#2abdbd'},
                       text=labels, textposition='top center', textfont={'family': 'calibri', 'size': 12, 'color': '#4f6978'})

layout = go.Layout(xaxis=axis_dict, yaxis=axis_dict)
fig = go.Figure(data=[plot_data], layout=layout)
iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="528ddd63-a2ee-4ef5-ac23-bb0f6453371e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("528ddd63-a2ee-4ef5-ac23-bb0f6453371e")) {                    Plotly.newPlot(                        "528ddd63-a2ee-4ef5-ac23-bb0f6453371e",                        [{"marker": {"color": "#2abdbd", "size": 4}, "mode": "markers+text", "text": ["launch", "social", "network", "called", "circle", "possibly", "today", "soundcloud", "start", "recording", "geotagging", "major", "goog", "goer", "droppin", "survival", "tip", "week", "help", "rock", "best", "hangover", "cure", "tamale", "house", "anyone", "chance", "check", "store", "wondering", "worth", "trek", "convention", "center", "pedicab", "charger", "would", "epic", "like", "girl", "scout", "planting", "next", "bank", "atm", "money", "#", "thinmints", "wish", "listening", "marissa", "mayer", "discus", "product", "including", "hotpot", "watch", "yelp", "fret", "owner", "open", "temporary", "launching", "turned", "giant", "camera", "look", "plain", "stupid", "future", "power", "paired", "augmented", "reality", "contextual", "pnid", "holler", "gram", "itunes", "sters", "great", "madebymany", "free", "thekills", "interview", "painfully", "vacuous", "history", "miss", "presentation", "circusmash", "filmaster", "mobile", "officially", "launched", "project", "street", "view", "except", "museum", "around", "world", "incl", "billion", "pixel", "image", "starry", "night", "dang", "route", "traffic", "saving", "driver", "year", "time", "finding", "ubersocial", "includes", "uberguide", "sponsored", "finally", "everyone", "facebook", "introduces", "fair", "stop", "innovation", "people", "zite", "intelligent", "magazine", "deliciousness", "trending", "youneedthis", "circles", "seeing", "map", "building", "super", "fast", "rendering", "edchat", "musedchat", "classical", "newtwitter", "pretty", "neat", "database", "must", "doe", "work", "android", "shall", "party", "showing", "tapworthy", "journal", "momento", "sale", "grab", "mashable", "closure", "form", "austin", "found", "proof", "lactation", "room", "excuse", "mother", "brought", "last", "fan", "town", "gtug", "meeting", "wednesday", "million", "user", "lemonade", "stand", "day", "startupbus", "ever", "wonder", "capture", "atx", "think", "nice", "retail", "peep", "design", "headache", "tablet", "call", "morning", "interviewed", "twit", "handing", "win", "fuel", "seo", "sem", "googlemaps", "topnews", "holla", "butt", "rumor", "true", "come", "play", "booth", "exhibit", "hall", "tell", "know", "mean", "winning", "going", "meet", "phone", "show", "loom", "nerd", "singapore", "roar", "sgroars", "someone", "hack", "square", "screen", "tech", "amazing", "selling", "california", "cult", "following", "brings", "netflix", "style", "functionality", "place", "result", "personality", "bettersearch", "every", "lone", "dude", "awaits", "likely", "expected", "bigger", "crowd", "forming", "technology", "marketing", "genius", "usage", "surprised", "north", "rule", "ooing", "ahing", "deal", "everybody", "bing", "smackdown", "bloody", "banality", "guardian", "wifi", "geek", "nearby", "please", "sharing", "frostwire", "issued", "update", "apps", "distract", "pub", "khoi", "vinh", "instead", "focusing", "reader", "delivering", "content", "way", "apparently", "preference", "seenocreepy", "added", "flight", "matching", "plane", "airport", "also", "downloaded", "nicely", "done", "photo", "made", "hosted", "aclu", "actually", "using", "make", "want", "aron", "pilhofer", "endorsed", "html", "newsapps", "asked", "tweet", "said", "preview", "networking", "platform", "conference", "could", "spend", "teaching", "theater", "alone", "schedule", "resurgence", "print", "boomer", "grid", "layout", "gatorade", "vom", ...
